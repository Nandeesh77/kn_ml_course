# %% [markdown]
# ### Machine Learning

# %% [markdown]
# Machine leanring is field of study that gives the computer the ability to learn without being explictly programeed.

# %% [markdown]
# #### Types

# %% [markdown]
# Supervised learning: it's type machine leaning where the model is been on labelled data. or The model or algorithm is presented with example inputs and their desired outputs and then finds patterns and connections between the input and the output
#
#
# Example : Image Classification,Market Prediction/Regression:

# %% [markdown]
# Unsupervised learning: No labels are given to the learning algorithm, leaving it on its own to find structure in its input.
#
# Example : Clustering,Generative Models
