#         [-2.72138715e-02,  3.05497982e-02,  3.54150049e-02,
#           2.54348181e-02,  6.93607330e-03,  2.62346752e-02,
#          -1.16283298e-02,  8.64697620e-03, -3.73101234e-03,
#           7.57894665e-03],
#         [ 2.86917947e-02, -3.63161191e-02,  2.66373493e-02,
#           3.86705659e-02, -1.69669874e-02, -1.49530768e-02,
#           3.16990502e-02, -1.99085474e-02,  3.22141498e-03,
#           4.22480740e-02],
#         [-4.36161160e-02,  9.83309746e-03,  3.24168839e-02,
#           3.38496007e-02, -6.52781874e-03,  2.92331837e-02,
#          -4.85804677e-02, -2.66754031e-02,  4.72464822e-02,
#          -3.70687135e-02]],
#
#        [[-5.72295114e-03,  1.71792842e-02,  2.03714035e-02,
#           4.03834619e-02,  4.68485691e-02,  1.95269473e-02,
#          -2.05327868e-02, -1.57625191e-02,  4.86894734e-02,
#          -2.72217281e-02],
#         [-5.72295114e-03,  1.71792842e-02,  2.03714035e-02,
#           4.03834619e-02,  4.68485691e-02,  1.95269473e-02,
#          -2.05327868e-02, -1.57625191e-02,  4.86894734e-02,
#          -2.72217281e-02],
#         [-5.72295114e-03,  1.71792842e-02,  2.03714035e-02,
#           4.03834619e-02,  4.68485691e-02,  1.95269473e-02,
#          -2.05327868e-02, -1.57625191e-02,  4.86894734e-02,
#          -2.72217281e-02],
#         [-5.72295114e-03,  1.71792842e-02,  2.03714035e-02,
#           4.03834619e-02,  4.68485691e-02,  1.95269473e-02,
#          -2.05327868e-02, -1.57625191e-02,  4.86894734e-02,
#          -2.72217281e-02],
#         [-3.23424228e-02,  4.50203158e-02,  1.83862559e-02,
#          -2.08428744e-02, -4.34316397e-02,  1.66163184e-02,
#           1.29255392e-02,  3.92790698e-02,  3.03137787e-02,
#           3.59928645e-02],
#         [-5.14298677e-03,  2.42139809e-02, -3.35647017e-02,
#           4.55423333e-02,  4.81294878e-02, -4.61478718e-02,
#           1.14053264e-02,  4.92800958e-02, -2.95424219e-02,
#           2.68811323e-02],
#         [ 3.68159898e-02,  3.17098983e-02, -9.63099301e-05,
#          -2.27023009e-02,  3.27581204e-02,  8.56890529e-03,
#           1.30180269e-03, -3.74347568e-02,  2.46853344e-02,
#           2.86524035e-02],
#         [-1.17833726e-02,  1.06214285e-02,  1.04284659e-02,
#           4.34102528e-02,  1.89997293e-02, -2.85959244e-03,
#          -3.76046784e-02, -2.05653906e-02, -4.23371792e-04,
#          -4.20059785e-02]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 9779, 5513, 1251, 2686])

# %%
model.predict(embedded_docs[0])
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nande\AppData\Local\Temp\ipykernel_14692\2831431483.py", line 1, in <module>
#     model.predict(embedded_docs[0],shape=embedded_docs[0].shape)
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 119, in error_handler
#     filtered_tb = _process_traceback_frames(e.__traceback__)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: TensorFlowTrainer.predict() got an unexpected keyword argument 'shape'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\IPython\core\ultratb.py", line 1454, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\IPython\core\ultratb.py", line 1345, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\IPython\core\ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\IPython\core\ultratb.py", line 1179, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\stack_data\core.py", line 597, in stack_data
#     yield from collapse_repeated(
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\stack_data\utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\stack_data\core.py", line 587, in mapper
#     return cls(f, options)
#            ^^^^^^^^^^^^^^^
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\stack_data\core.py", line 551, in __init__
#     self.executing = Source.executing(frame_or_tb)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\executing\executing.py", line 283, in executing
#     assert_(new_stmts <= stmts)
#   File "c:\Nandeesh\git\kn_ml_course\venv\Lib\site-packages\executing\executing.py", line 80, in assert_
#     raise AssertionError(str(message))
# AssertionError
